# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or plain Regex
* Do not add anycomments of commentary or explanation

"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
import re
import ast

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0
      
def grade_syntax(response, test_case):
    format_type = test_case["format"]
    if format_type == "json":
        return validate_json(response)
    elif format_type == "python":
        return validate_python(response)
    elif format_type == "regex":
        return validate_regex(response)
    else:
        raise ValueError(f"Unknown format type: {format_type}")

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    
    syntax_score = grade_syntax(output, test_case)
    
    score = (model_score + syntax_score) / 2  # Average of model score and syntax score

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS EC2 Instance ID Extractor from CloudTrail Logs\n\nHere's a solution to extract EC2 instance IDs from CloudTrail logs:\n\n```python\nimport re\nimport json\nfrom typing import List, Set\n\ndef extract_ec2_instance_ids(log_data: str) -> Set[str]:\n    \"\"\"\n    Extract AWS EC2 instance IDs from CloudTrail logs.\n    \n    EC2 instance IDs follow the pattern: i- followed by hexadecimal characters\n    Pattern: i-[0-9a-f]{17} (standard format)\n    \n    Args:\n        log_data: CloudTrail log content (string or JSON)\n    \n    Returns:\n        Set of unique EC2 instance IDs found\n    \"\"\"\n    # Pattern for EC2 instance IDs: i- followed by 17 hex characters\n    pattern = r'i-[0-9a-f]{17}'\n    \n    # Find all matches\n    instance_ids = set(re.findall(pattern, log_data, re.IGNORECASE))\n    \n    return instance_ids\n\n\ndef extract_from_json_logs(json_logs: List[dict]) -> Set[str]:\n    \"\"\"\n    Extract instance IDs from CloudTrail JSON log entries.\n    \n    Args:\n        json_logs: List of CloudTrail log event dictionaries\n    \n    Returns:\n        Set of unique EC2 instance IDs found\n    \"\"\"\n    instance_ids = set()\n    \n    for event in json_logs:\n        # Convert event to string to search through all fields\n        event_str = json.dumps(event)\n        ids = extract_ec2_instance_ids(event_str)\n        instance_ids.update(ids)\n    \n    return instance_ids\n\n\n# Example usage\nif __name__ == \"__main__\":\n    # Example 1: Text-based CloudTrail log\n    sample_log = \"\"\"\n    {\n        \"eventName\": \"RunInstances\",\n        \"requestParameters\": {\n            \"instancesSet\": {\n                \"items\": [{\"instanceId\": \"i-0a1b2c3d4e5f6g7h8\"}]\n            }\n        },\n        \"responseElements\": {\n            \"instancesSet\": {\n                \"items\": [{\"instanceId\": \"i-1234567890abcdef0\"}]\n            }\n        },\n        \"eventName\": \"TerminateInstances\",\n        \"requestParameters\": \"i-abcdef0123456789a\"\n    }\n    \"\"\"\n    \n    ids = extract_ec2_instance_ids(sample_log)\n    print(\"Found Instance IDs:\")\n    for instance_id in sorted(ids):\n        print(f\"  - {instance_id}\")\n    \n    # Example 2: From JSON-structured logs\n    print(\"\\n\" + \"=\"*50 + \"\\n\")\n    \n    json_log_events = [\n        {\n            \"eventName\": \"RunInstances\",\n            \"responseElements\": {\n                \"instancesSet\": {\n                    \"items\": [\n                        {\"instanceId\": \"i-0123456789abcdef0\"},\n                        {\"instanceId\": \"i-fedcba9876543210a\"}\n                    ]\n                }\n            }\n        },\n        {\n            \"eventName\": \"StopInstances\",\n            \"requestParameters\": {\n                \"instancesSet\": {\n                    \"items\": [\n                        {\"instanceId\": \"i-1111111111111111a\"}\n                    ]\n                }\n            }\n        }\n    ]\n    \n    ids_from_json = extract_from_json_logs(json_log_events)\n    print(\"Instance IDs from JSON logs:\")\n    for instance_id in sorted(ids_from_json):\n        print(f\"  - {instance_id}\")\n```\n\n## Features:\n\n\u2705 **Regex Pattern**: `i-[0-9a-f]{17}` matches standard EC2 instance IDs\n\u2705 **Case-Insensitive**: Handles both lowercase and uppercase hex characters\n\u2705 **Deduplication**: Returns unique IDs using a Set\n\u2705 **Two Functions**:",
#     "test_case": {
#       "task": "Extract AWS EC2 instance IDs from CloudTrail logs. Instance IDs follow the pattern 'i-' followed by hexadecimal characters.",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the core task with an accurate regex pattern and clean implementation. The regex properly enforces the i- prefix with exactly 17 hex characters. However, the example usage undermines credibility by including an intentionally invalid instance ID without explanation. The lack of error handling and edge case consideration makes this less production-ready for real CloudTrail processing where data quality varies. Despite these issues, the fundamental approach is sound and would work correctly for well-formed inputs."
#   },
#   {
#     "output": "# AWS S3 Bucket Policy Parser\n\nI'll create a comprehensive solution to parse AWS S3 bucket policies and extract principals with their permissions.\n\n```python\nimport json\nfrom typing import Dict, List, Set, Any, Union\nfrom dataclasses import dataclass, asdict\n\n@dataclass\nclass Permission:\n    \"\"\"Represents a permission granted to a principal\"\"\"\n    action: str\n    resource: str\n    effect: str\n    condition: Dict[str, Any] = None\n\n@dataclass\nclass Principal:\n    \"\"\"Represents a principal with their permissions\"\"\"\n    identifier: str\n    principal_type: str  # AWS, Service, Federated, CanonicalUser, *\n    permissions: List[Permission] = None\n    \n    def __post_init__(self):\n        if self.permissions is None:\n            self.permissions = []\n\nclass S3BucketPolicyParser:\n    \"\"\"Parse and extract information from AWS S3 bucket policies\"\"\"\n    \n    def __init__(self, policy_json: Union[str, Dict]):\n        \"\"\"\n        Initialize parser with policy JSON\n        \n        Args:\n            policy_json: JSON string or dictionary containing the policy\n        \"\"\"\n        if isinstance(policy_json, str):\n            self.policy = json.loads(policy_json)\n        else:\n            self.policy = policy_json\n    \n    def parse(self) -> Dict[str, Any]:\n        \"\"\"\n        Parse the bucket policy and extract all information\n        \n        Returns:\n            Dictionary containing structured policy information\n        \"\"\"\n        result = {\n            \"policy_version\": self.policy.get(\"Version\"),\n            \"principals\": {},\n            \"summary\": {\n                \"total_statements\": len(self.policy.get(\"Statement\", [])),\n                \"allowed_statements\": 0,\n                \"denied_statements\": 0,\n                \"unique_principals\": set(),\n                \"all_actions\": set()\n            }\n        }\n        \n        statements = self.policy.get(\"Statement\", [])\n        \n        for statement in statements:\n            self._process_statement(statement, result)\n        \n        # Convert sets to lists for JSON serialization\n        result[\"summary\"][\"unique_principals\"] = list(result[\"summary\"][\"unique_principals\"])\n        result[\"summary\"][\"all_actions\"] = list(result[\"summary\"][\"all_actions\"])\n        \n        return result\n    \n    def _process_statement(self, statement: Dict, result: Dict) -> None:\n        \"\"\"Process a single statement and extract principal/permission info\"\"\"\n        effect = statement.get(\"Effect\", \"Allow\")\n        actions = self._normalize_list(statement.get(\"Action\", []))\n        resources = self._normalize_list(statement.get(\"Resource\", []))\n        principals = statement.get(\"Principal\", {})\n        conditions = statement.get(\"Condition\")\n        \n        # Update summary\n        if effect == \"Allow\":\n            result[\"summary\"][\"allowed_statements\"] += 1\n        else:\n            result[\"summary\"][\"denied_statements\"] += 1\n        \n        result[\"summary\"][\"all_actions\"].update(actions)\n        \n        # Handle different principal formats\n        principal_list = self._extract_principals(principals)\n        \n        for principal_id, principal_type in principal_list:\n            result[\"summary\"][\"unique_principals\"].add(principal_id)\n            \n            if principal_id not in result[\"principals\"]:\n                result[\"principals\"][principal_id] = {\n                    \"type\": principal_type,\n                    \"permissions\": []\n                }\n            \n            # Add permissions for this principal\n            for action in actions:\n                for resource in resources:\n                    permission = {\n                        \"action\": action,\n                        \"resource\": resource,\n                        \"effect\": effect,\n          ...
#     "test_case": {
#       "task": "Parse an AWS S3 bucket policy JSON and extract all allowed principals and their permissions",
#       "format": "python"
#     },
#     "score": 4,
#     "reasoning": "The solution demonstrates good architectural design and understanding of AWS S3 policies, but it is incomplete and would not execute successfully. The truncated `_extract_principals()` method is essential for extracting principals from different formats (string wildcard '*', dictionaries with principal types like AWS/Service/etc.). Additionally, there's no error handling for common issues like invalid JSON or missing policy fields. The code also defines dataclasses (Permission, Principal) upfront but never uses them in the actual implementation, suggesting incomplete refactoring."
#   },
#   {
#     "output": "# CloudFormation Template for AWS Lambda Function\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function with basic execution role and environment variables\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"lambda-execution-role\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-lambda-function\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.handler\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Code\": {\n          \"ZipFile\": \"import json\\nimport os\\n\\ndef handler(event, context):\\n    env_var1 = os.environ.get('ENV_VAR1')\\n    env_var2 = os.environ.get('ENV_VAR2')\\n    \\n    return {\\n        'statusCode': 200,\\n        'body': json.dumps({\\n            'message': 'Hello from Lambda!',\\n            'env_var1': env_var1,\\n            'env_var2': env_var2\\n        })\\n    }\\n\"\n        },\n        \"Environment\": {\n          \"Variables\": {\n            \"ENV_VAR1\": \"value1\",\n            \"ENV_VAR2\": \"value2\",\n            \"ENVIRONMENT\": \"development\"\n          }\n        },\n        \"Timeout\": 30,\n        \"MemorySize\": 128,\n        \"Description\": \"Lambda function with environment variables\"\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    },\n    \"LambdaExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n### 1. **IAM Execution Role**\n- Allows Lambda service to assume the role\n- Includes `AWSLambdaBasicExecutionRole` managed policy for CloudWatch Logs access\n\n### 2. **Lambda Function**\n- **Runtime**: Python 3.11 (adjustable)\n- **Handler**: `index.handler` (entry point)\n- **Code**: Inline Python code as `ZipFile`\n- **Environment Variables**: Custom variables accessible in code via `os.environ.get()`\n\n### 3. **Environment Variables**\n- `ENV_VAR1`: value1\n- `ENV_VAR2`: value2\n- `ENVIRONMENT`: development\n\n### 4. **Function Properties**\n- **Timeout**: 30 seconds\n- **Memory**: 128 MB\n-",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON structure for an AWS Lambda function with basic execution role and environment variables",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully addresses the core task requirements with a valid, deployable CloudFormation template. The IAM role configuration is correct and the Lambda function properly references it. Environment variables are correctly implemented and demonstrated in the handler code. However, the hardcoded RoleName is a significant production concern, and lack of parameterization limits reusability. These are refinable issues rather than fundamental flaws. The template would work as-is but should be improved for production use."
#   }
# ]
