# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Requirement already satisfied: voyageai in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (0.3.11)
# Requirement already satisfied: tokenizers>=0.14.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (0.22.2)
# Requirement already satisfied: numpy in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (2.0.2)
# Requirement already satisfied: tenacity in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (9.1.2)
# Requirement already satisfied: aiohttp in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (3.13.5)
# Requirement already satisfied: aiolimiter in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (1.2.1)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (2.13.4)
# Requirement already satisfied: requests in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (2.32.5)
# Requirement already satisfied: pillow in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from voyageai) (11.3.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-text-splitters>=0.3.8->voyageai) (0.3.86)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (25.0)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (6.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.11.5)
# Requirement already satisfied: anyio in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.12.1)
# Requirement already satisfied: certifi in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: idna in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->voyageai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->voyageai) (2.46.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from requests->voyageai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from requests->voyageai) (3.4.9)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from tokenizers>=0.14.0->voyageai) (1.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.70.0)
# Requirement already satisfied: typer in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.23.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.19.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (1.22.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (26.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (6.7.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (0.4.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from aiohttp->voyageai) (5.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (8.1.8)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.0.5)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (15.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/felipesouza/claude-study/.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/felipesouza/claude-study/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Client Setup
import os
from dotenv import load_dotenv
import voyageai

load_dotenv(dotenv_path="../.env")

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 6
#       2     text = f.read()
#       4 chunks = chunk_by_section(text)
# ----> 6 generate_embedding(chunks[0])
#
# Cell In[5], line 3, in generate_embedding(text, model, input_type)
#       2 def generate_embedding(text, model="voyage-3-large", input_type="query"):
# ----> 3     result = client.embed([text], model=model, input_type=input_type)
#       5     return result.embeddings[0]
#
# File ~/claude-study/.venv/lib/python3.9/site-packages/voyageai/client.py:96, in Client.embed(self, texts, model, input_type, truncation, output_dtype, output_dimension)
#      86     return embed_local(
#      87         texts=texts,
#      88         model=model,
#    (...)
#      92         output_dimension=output_dimension,
#      93     )
#      95 # API models require an API key
# ---> 96 self._require_api_key()
#      98 response = None
#      99 for attempt in self._make_retry_controller():
#
# File ~/claude-study/.venv/lib/python3.9/site-packages/voyageai/_base.py:95, in _BaseClient._require_api_key(self)
#      87 """Raise a clear error if no API key is configured.
#      88
#      89 The client allows a missing key so local models can run without one, but
#    (...)
#      92 the request layer with a less actionable error.
#      93 """
#      94 if not self.api_key:
# ---> 95     raise AuthenticationError(
#      96         "An API key is required for API-based models. "
#      97         "Set your API key via the VOYAGE_API_KEY environment variable or "
#      98         "pass it to the client (api_key=...)."
#      99     )
#
# AuthenticationError: An API key is required for API-based models. Set your API key via the VOYAGE_API_KEY environment variable or pass it to the client (api_key=...).
